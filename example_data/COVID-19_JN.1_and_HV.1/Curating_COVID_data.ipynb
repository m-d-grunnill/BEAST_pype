# %% [markdown]
# # Curating COVID example data
#
#
# Canadian HV.1 and JN.1 data was downloaded on 2026-01-14 from [ViruSeq Portal](https://virusseq-dataportal.ca/explorer?filters=%7B%22content%22%3A%5B%7B%22content%22%3A%7B%22fieldName%22%3A%22analysis.first_published_at%22%2C%22value%22%3A1696132800000%7D%2C%22op%22%3A%22%3E%3D%22%7D%2C%7B%22content%22%3A%7B%22fieldName%22%3A%22analysis.first_published_at%22%2C%22value%22%3A1704085199999%7D%2C%22op%22%3A%22%3C%3D%22%7D%2C%7B%22content%22%3A%7B%22fieldName%22%3A%22analysis.lineage_analysis.lineage_name%22%2C%22value%22%3A%5B%22HV.1%22%2C%22JN.1%22%2C%22JN.1.1%22%2C%22JN.1.10%22%2C%22JN.1.18%22%2C%22JN.1.19%22%2C%22JN.1.2%22%2C%22JN.1.22%22%2C%22JN.1.31%22%2C%22JN.1.39%22%2C%22JN.1.4%22%2C%22JN.1.4.5%22%2C%22JN.1.4.7%22%2C%22JN.1.41%22%2C%22JN.1.44%22%2C%22JN.1.45%22%2C%22JN.1.47.1%22%2C%22JN.1.5%22%2C%22JN.1.52%22%2C%22JN.1.55%22%2C%22JN.1.6%22%2C%22JN.1.60%22%2C%22JN.1.8%22%2C%22JN.1.8.3%22%2C%22JN.1.9%22%2C%22JN.11%22%2C%22JN.13%22%2C%22JN.18%22%5D%7D%2C%22op%22%3A%22in%22%7D%5D%2C%22op%22%3A%22and%22%7D) by selecting all data submitted between 2023-10-01 and 2023-12-31 with lineage name equal to 'HV.1', 'JN.1' or starting with 'JN.1.'.
#
# Sequence used for reference in aligning was MN908947.3 downloaded from https://www.ncbi.nlm.nih.gov/nuccore/MN908947.3?report=fasta on 2026-01-14.
#
# ## Explore metadata
#
# Import necessary packages

# %%
import pandas as pd
import Bio.SeqIO
from Bio.Seq import Seq
from tqdm import tqdm
from pandas.tseries.offsets import DateOffset

# %%
metadata = pd.read_csv('virusseq-search-export/metadata.tsv',sep='\t', parse_dates=[ 'submission date', 'sample collection date'])

# %%
metadata.head()
# Out:
#   study_id specimen collector sample ID lineage name  \
# 0  LSPQ-QC                    QC_678503      JN.1.22
# 1   PHO-ON                    ON_678100      JN.1.22
# 2  LSPQ-QC                    QC_671507       JN.1.1
# 3   PHO-ON                    ON_669608       JN.1.6
# 4  LSPQ-QC                    QC_678509      JN.1.22
#
#   lineage analysis software name lineage analysis software version  \
# 0                       pangolin                             4.3.1
# 1                       pangolin                             4.3.1
# 2                       pangolin                             4.3.1
# 3                       pangolin                             4.3.1
# 4                       pangolin                             4.3.1
#
#   lineage analysis software data version         scorpio call scorpio version  \
# 0                          PANGO-v1.25.1  Omicron (BA.2-like)          0.3.19
# 1                          PANGO-v1.25.1  Omicron (BA.2-like)          0.3.19
# 2                            PANGO-v1.24  Omicron (BA.2-like)          0.3.19
# 3                            PANGO-v1.24  Omicron (BA.2-like)          0.3.19
# 4                          PANGO-v1.25.1  Omicron (BA.2-like)          0.3.19
#
#                               sample collected by  \
# 0  Laboratoire de santé publique du Québec (LSPQ)
# 1                     Public Health Ontario (PHO)
# 2  Laboratoire de santé publique du Québec (LSPQ)
# 3                     Public Health Ontario (PHO)
# 4  Laboratoire de santé publique du Québec (LSPQ)
#
#                             sequence submitted by  ...  \
# 0  Laboratoire de santé publique du Québec (LSPQ)  ...
# 1                     Public Health Ontario (PHO)  ...
# 2  Laboratoire de santé publique du Québec (LSPQ)  ...
# 3                     Public Health Ontario (PHO)  ...
# 4  Laboratoire de santé publique du Québec (LSPQ)  ...
#
#   consensus sequence software version breadth of coverage value  \
# 0                               1.3.4                     99.6%
# 1                               1.3.2                     99.6%
# 2                               1.3.4                     99.6%
# 3                               1.3.2                     99.6%
# 4                               1.3.4                     99.6%
#
#    depth of coverage value reference genome accession  \
# 0                    5257x                 MN908947.3
# 1                     907x                 MN908947.3
# 2                    3587x                 MN908947.3
# 3                     639x                 MN908947.3
# 4                    5241x                 MN908947.3
#
#                              bioinformatics protocol      gene name  \
# 0  https://bitbucket.org/mugqic/genpipes/src/mast...   Not Provided
# 1  https://github.com/jts/ncov2019-artic-nf/blob/...  E gene (orf4)
# 2  https://bitbucket.org/mugqic/genpipes/src/mast...   Not Provided
# 3  https://github.com/jts/ncov2019-artic-nf/blob/...  E gene (orf4)
# 4  https://bitbucket.org/mugqic/genpipes/src/mast...   Not Provided
#
#   diagnostic pcr Ct value diagnostic pcr Ct value null reason  \
# 0                     NaN                        Not Provided
# 1                   23.03                                 NaN
# 2                     NaN                        Not Provided
# 3                   21.60                                 NaN
# 4                     NaN                        Not Provided
#
#    GISAID accession last updated at
# 0  EPI_ISL_18586351      2024-11-06
# 1  EPI_ISL_18581888      2024-11-06
# 2  EPI_ISL_18535065      2024-11-06
# 3  EPI_ISL_18505034      2024-11-06
# 4  EPI_ISL_18586357      2024-11-06
#
# [5 rows x 50 columns]

# %% [markdown]
# Counts of lineages

# %%
metadata['lineage name'].value_counts()
# Out:
# lineage name
# HV.1         6301
# JN.1          179
# JN.1.1         80
# JN.1.4         49
# JN.1.2         47
# JN.1.22        21
# JN.18          17
# JN.1.31        10
# JN.1.4.5        9
# JN.1.9          5
# JN.11           4
# JN.1.47.1       3
# JN.1.19         2
# JN.13           2
# JN.1.5          2
# JN.1.6          2
# JN.1.41         1
# JN.1.44         1
# JN.1.45         1
# JN.1.8.3        1
# JN.1.10         1
# JN.1.60         1
# JN.1.52         1
# JN.1.8          1
# JN.1.4.7        1
# JN.1.39         1
# JN.1.55         1
# JN.1.18         1
# Name: count, dtype: int64

# %% [markdown]
# How many JN.1 & all its sublineages

# %%
len(metadata[metadata['lineage name']!='HV.1'])
# Out:
# 444

# %% [markdown]
# Collection date data for all HV.1.

# %%
metadata[metadata['lineage name']=='HV.1']['sample collection date'].describe()
# Out:
# count                             6301
# mean     2023-10-28 06:11:35.889541376
# min                2023-08-15 00:00:00
# 25%                2023-10-14 00:00:00
# 50%                2023-11-01 00:00:00
# 75%                2023-11-14 00:00:00
# max                2023-12-08 00:00:00
# Name: sample collection date, dtype: object

# %% [markdown]
# Collection date data for all JN.1 and its sublineages.

# %%
metadata[metadata['lineage name']!='HV.1']['sample collection date'].describe()
# Out:
# count                              444
# mean     2023-11-18 01:30:48.648648704
# min                2023-10-09 00:00:00
# 25%                2023-11-13 00:00:00
# 50%                2023-11-21 00:00:00
# 75%                2023-11-25 00:00:00
# max                2023-12-09 00:00:00
# Name: sample collection date, dtype: object

# %% [markdown]
# ## Aligning and masking Sequences
#
# Sequences will be aligned using Nextclade.
#
# ### Obtaining Reference genome

# %%
# %%bash
# source activate beast_pype_data_curation
# nextclade dataset get --name 'nextstrain/sars-cov-2/wuhan-hu-1/orfs' --output-dir 'nextclade-sars-cov-2'

# %% [markdown]
# ### Align Sequences

# %%
# %%bash
# source activate beast_pype_data_curation
# nextclade run \
#    --input-dataset nextclade-sars-cov-2 \
#    --output-all=output/ \
#    virusseq-search-export/sequences.fasta
# mv output/nextclade.aligned.fasta HV_1_and_JN_1_sequences.fasta

# %% [markdown]
# ## Putting JN.1 Sequences in there own dataset

# %%
JN1_ids = metadata[metadata['lineage name']!='HV.1']['fasta header name'].to_list()
HV1_and_JN1_sequences = []
JN1_sequences = []

for record in tqdm(Bio.SeqIO.parse('HV_1_and_JN_1_sequences.fasta', 'fasta')):
    if record.id in JN1_ids:
        JN1_sequences.append(record)
with open('JN_1_sequences.fasta', 'w') as file:
    Bio.SeqIO.write(JN1_sequences, file, 'fasta')
file.close()
# Out:
# 6745it [00:03, 2024.42it/s]

# %% [markdown]
# ## Saving the metadata for HV_1_and_JN_1_sequences.fasta and JN_1_sequences.fasta

# %%
metadata[metadata['lineage name']!='HV.1'].to_csv('JN_1_metadata.csv', index=False)
metadata.to_csv('HV_1_and_JN_1_metadata.csv', index=False)

# %%
sorted(metadata['lineage name'].unique().tolist())
# Out:
# ['HV.1',
#  'JN.1',
#  'JN.1.1',
#  'JN.1.10',
#  'JN.1.18',
#  'JN.1.19',
#  'JN.1.2',
#  'JN.1.22',
#  'JN.1.31',
#  'JN.1.39',
#  'JN.1.4',
#  'JN.1.4.5',
#  'JN.1.4.7',
#  'JN.1.41',
#  'JN.1.44',
#  'JN.1.45',
#  'JN.1.47.1',
#  'JN.1.5',
#  'JN.1.52',
#  'JN.1.55',
#  'JN.1.6',
#  'JN.1.60',
#  'JN.1.8',
#  'JN.1.8.3',
#  'JN.1.9',
#  'JN.11',
#  'JN.13',
#  'JN.18']

# %%
metadata.columns
# Out:
# Index(['study_id', 'specimen collector sample ID', 'lineage name',
#        'lineage analysis software name', 'lineage analysis software version',
#        'lineage analysis software data version', 'scorpio call',
#        'scorpio version', 'sample collected by', 'sequence submitted by',
#        'submission date', 'sample collection date',
#        'sample collection date null reason', 'geo_loc_name (country)',
#        'geo_loc_name (state/province/territory)', 'organism', 'isolate',
#        'fasta header name', 'purpose of sampling',
#        'purpose of sampling details', 'anatomical material', 'anatomical part',
#        'body product', 'environmental material', 'environmental site',
#        'collection device', 'collection method', 'host (scientific name)',
#        'host disease', 'host age null reason', 'host age unit', 'host age bin',
#        'host gender', 'purpose of sequencing', 'purpose of sequencing details',
#        'sequencing instrument', 'sequencing protocol',
#        'raw sequence data processing method', 'dehosting method',
#        'consensus sequence software name',
#        'consensus sequence software version', 'breadth of coverage value',
#        'depth of coverage value', 'reference genome accession',
#        'bioinformatics protocol', 'gene name', 'diagnostic pcr Ct value',
#        'diagnostic pcr Ct value null reason', 'GISAID accession',
#        'last updated at'],
#       dtype='object')
